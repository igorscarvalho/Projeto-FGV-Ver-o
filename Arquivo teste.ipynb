# %% [markdown]
# # Script teste

# %%
from math import pi
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
a = 3*pi

# %%
print("Três vezes pi é: {}".format(a))
# Out:
# Três vezes pi é: 9.42477796076938

# %%
l = np.array([2,3,4,3,4,5,7,3,4,8,3,4,8,3,7])

# %%
plt.plot(l, color = 'green')
plt.show()
#plt.title('Apenas um teste...')

# %%
plt.scatter(l, l-2, color = 'orange')
plt.show()

# %%
plt.hist(l, color = 'gray')
plt.show()
